# %%
import sys
import os
sys.path.append('..')
import src.svm_utils as svm_utils
import src.visualization_utils as viz_utils
import src.ds_utils as ds_utils
import numpy as np
import pandas as pd
import seaborn as sns
import src.clip_utils as clip_utils
import torch
sns.set()

# %%
out = torch.load("/mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/svm_checkpoints/normalized_celeba_age_svm.pt")

# %%
BLUE = sns.color_palette("tab10")[0]
RED = sns.color_palette("tab10")[3]
ORANGE = sns.color_palette("tab10")[1]
BROWN = sns.color_palette("tab10")[5]
GRAY = sns.color_palette("tab10")[7]
GREEN = sns.color_palette("tab10")[2]

import matplotlib.pylab as pylab
params = {'legend.fontsize': 12,
          'figure.figsize': (5, 3),
         'axes.labelsize': 14,
         'axes.titlesize':16,
         'xtick.labelsize':14,
         'ytick.labelsize':14}
pylab.rcParams.update(params)

# %%
beton_root = "/mnt/cfs/projects/correlated_errors/betons"
experiment_root = "/mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/"

svm_name = "normalized_celeba_age_svm"
name = os.path.join(experiment_root, f"svm_checkpoints/{svm_name}.pt") # SVM output file
svm_model_name = os.path.join(experiment_root, f"svm_checkpoints/{svm_name}_model.pkl") # SVM output file

model_root = os.path.join(experiment_root, "models")
model_ckpt = os.path.join(model_root, "celeba_age_1_4/version_0/checkpoints/checkpoint_last.pt")
loss_upweight_root = os.path.join(experiment_root, "loss_vec_files")

# %%
processor = viz_utils.SVMProcessor(name, root=beton_root, checkpoint_path=model_ckpt, save_pred_probs=True)
# Out:
# -----------train_metrics--------------
# {'Confusion Matrix': array([[    1,     1],
#        [12925, 49103]]),
#  'Model Accuracy': 0.9999677575366758,
#  'SVM Accuracy': 0.7916169762611389,
#  'SVM Balanced Accuracy': 0.6458131670951843}
# -----------val_metrics--------------
# {'Confusion Matrix': array([[1667,  297],
#        [1569, 3647]]),
#  'Model Accuracy': 0.7264623955431755,
#  'SVM Accuracy': 0.7401114106178284,
#  'SVM Balanced Accuracy': 0.7739863991737366}
# -----------test_metrics--------------
# {'Confusion Matrix': array([[ 3077,   984],
#        [ 3238, 12663]]),
#  'Model Accuracy': 0.7965634705941288,
#  'SVM Accuracy': 0.7884981632232666,
#  'SVM Balanced Accuracy': 0.7770300805568695}
# Using default os_cache: False
# Using default quasi_random: True
# Using default val_aug: None
# Using default loss_vec_file: None
# Using default indices_file: None
# Using default unlabeled_beton: None
# Using default loss_upweight: 5
# Using default bce: False
# Using default cmnist: False
#
# -----------CONFIG--------------
# {   'arch': 'resnet18',
#     'arch_type': 'resnet',
#     'batch_size': 100,
#     'bce': False,
#     'cmnist': False,
#     'drop_last': False,
#     'imgsz': 75,
#     'indices_file': None,
#     'loss_upweight': 5,
#     'loss_vec_file': None,
#     'mean': [123.675, 116.28, 103.53],
#     'num_classes': 2,
#     'num_workers': 1,
#     'os_cache': False,
#     'quasi_random': True,
#     'shuffle': False,
#     'std': [58.395, 57.12, 57.375],
#     'test_beton': 'celeba_age/celeba_age_test.beton',
#     'train_aug': 'imagenet_train_aug',
#     'train_beton': 'celeba_age/celeba_age_train.beton',
#     'train_img_decoder': 'center_crop_full',
#     'training': {   'epochs': 30,
#                     'lr': 0.02,
#                     'lr_scheduler': {'lr_peak_epoch': 2, 'type': 'cyclic'},
#                     'optimizer': {'momentum': 0.9, 'weight_decay': 0.0005}},
#     'unlabeled_beton': None,
#     'val_aug': None,
#     'val_beton': 'celeba_age/celeba_age_val.beton',
#     'val_img_decoder': 'center_crop_full'}
# {'training_args': {'epochs': 30, 'lr': 0.02, 'optimizer': {'momentum': 0.9, 'weight_decay': 0.0005}, 'lr_scheduler': {'type': 'cyclic', 'lr_peak_epoch': 2}, 'iters_per_epoch': 121}, 'epoch': 29, 'training_metrics': {'loss': 0.0008372744730065677, 'acc': 0.9999354338842975}, 'val_metrics': {'loss': 1.7282812941705283, 'acc': 0.7264623955431755}}
# getting train loader
# getting val loader
# getting test loader
# 100%|██████████| 621/621 [00:11<00:00, 53.79it/s]
# Accuracy 0.9999677538871765
# 100%|██████████| 72/72 [00:01<00:00, 36.32it/s]
# Accuracy 0.7264624238014221
# 100%|██████████| 200/200 [00:02<00:00, 80.78it/s]
# Accuracy 0.796563446521759

# %%
# Get cross val scores 
def check_efficacy(split='test', is_correct=None):
    age = processor.metrics[f'{split}_metrics']['classes'] # 0 if female, 1 if male
    gender = processor.metrics[f'{split}_metrics']['spuriouses'] #1 if blond, 2 if black hair, 0 if neither
    if is_correct is None:
        is_correct = processor.metrics[f'{split}_metrics']['ytrue']
    age_masks = {
        'old': age == 0,
        'young': age == 1,
    }
    gender_masks = {
        'female': gender == 0,
        'male': gender == 1
    }
    df = []
    for a, a_m in age_masks.items():
        for g, g_m in gender_masks.items():
            acc = is_correct[g_m & a_m].mean()
            print(f"{a}, {g}, {is_correct[g_m & a_m].mean():0.4f}, {len(is_correct[g_m & a_m])}")
            df.append([a, g, is_correct[g_m & a_m].mean()])
    df.append(['overall', '', is_correct.mean()])
    return (age_masks, gender_masks), df

# %%
print("val")
val_masks, _ = check_efficacy("val")
print("\ntest")
test_masks, _ = check_efficacy("test")
print("\ntrain")
train_masks, _ = check_efficacy("train")
# Out:
# val
# old, female, 0.5242, 1795
# old, male, 0.8964, 1795
# young, female, 0.9153, 1795
# young, male, 0.5699, 1795
#
# test
# old, female, 0.5569, 1916
# old, male, 0.9038, 2932
# young, female, 0.9148, 10331
# young, male, 0.5714, 4783
#
# train
# old, female, 0.9998, 6203
# old, male, 1.0000, 24812
# young, female, 1.0000, 24812
# young, male, 1.0000, 6203

# %%
import torch

# model_fixes = ['celeba_age_1_4_balanced', 'celeba_age_1_4_soft',  'celeba_age_1_4_upweight_2',
#                'celeba_age_1_4_oracle_balanced', 'celeba_age_1_4_oracle_upweight_2']
model_fixes = ['celeba_age_1_4', 'celeba_svm_balanced', 'celeba_svm_oracle_2', 
               'celeba_svm_oracle_balance', 'celeba_svm_overweight_2', 'celeba_svm_soft']
df = []
for f in model_fixes:
    for v in range(5):
        print(f"\n===={f}=====")
        fix = torch.load(os.path.join(model_root, f, f"version_{v}/metrics.pt"))
        for split in ['val', 'test']:
            print(f"{split}")
            print(f"Accuracy {fix[split]['Accuracy']:0.4f}")
            intervene_is_correct = (fix[split]['classes'] == fix[split]['preds']).float()
            _, results = check_efficacy(split, intervene_is_correct.numpy())
            for r in results:
                df.append([f, split, r[0] + " " + r[1], r[2]])
df = pd.DataFrame(df, columns=["Method", "Split", "Age and Gender", "Acc"])
# Out:
# ====celeba_age_1_4=====
# val
# Accuracy 0.7265
# old, female, 0.5242, 1795
# old, male, 0.8964, 1795
# young, female, 0.9153, 1795
# young, male, 0.5699, 1795
# test
# Accuracy 0.7966
# old, female, 0.5569, 1916
# old, male, 0.9038, 2932
# young, female, 0.9148, 10331
# young, male, 0.5714, 4783
#
# ====celeba_age_1_4=====
# val
# Accuracy 0.7255
# old, female, 0.5226, 1795
# old, male, 0.8953, 1795
# young, female, 0.9203, 1795
# young, male, 0.5638, 1795
# test
# Accuracy 0.7932
# old, female, 0.5329, 1916
# old, male, 0.9079, 2932
# young, female, 0.9152, 10331
# young, male, 0.5637, 4783
#
# ====celeba_age_1_4=====
# val
# Accuracy 0.7326
# old, female, 0.5460, 1795
# old, male, 0.8897, 1795
# young, female, 0.9220, 1795
# young, male, 0.5727, 1795
# test
# Accuracy 0.7920
# old, female, 0.5418, 1916
# old, male, 0.9042, 2932
# young, female, 0.9135, 10331
# young, male, 0.5609, 4783
#
# ====celeba_age_1_4=====
# val
# Accuracy 0.7220
# old, female, 0.5109, 1795
# old, male, 0.8936, 1795
# young, female, 0.9192, 1795
# young, male, 0.5643, 1795
# test
# Accuracy 0.7953
# old, female, 0.5465, 1916
# old, male, 0.9031, 2932
# young, female, 0.9125, 10331
# young, male, 0.5758, 4783
#
# ====celeba_age_1_4=====
# val
# Accuracy 0.7265
# old, female, 0.5354, 1795
# old, male, 0.8797, 1795
# young, female, 0.9153, 1795
# young, male, 0.5755, 1795
# test
# Accuracy 0.7956
# old, female, 0.5339, 1916
# old, male, 0.9031, 2932
# young, female, 0.9185, 10331
# young, male, 0.5689, 4783
#
# ====celeba_svm_balanced=====
# val
# Accuracy 0.7347
# old, female, 0.5643, 1795
# old, male, 0.8724, 1795
# young, female, 0.8919, 1795
# young, male, 0.6100, 1795
# test
# Accuracy 0.7872
# old, female, 0.5793, 1916
# old, male, 0.8834, 2932
# young, female, 0.8923, 10331
# young, male, 0.5846, 4783
#
# ====celeba_svm_balanced=====
# val
# Accuracy 0.7315
# old, female, 0.5610, 1795
# old, male, 0.8763, 1795
# young, female, 0.8942, 1795
# young, male, 0.5944, 1795
# test
# Accuracy 0.7864
# old, female, 0.5741, 1916
# old, male, 0.8977, 2932
# young, female, 0.8873, 10331
# young, male, 0.5852, 4783
#
# ====celeba_svm_balanced=====
# val
# Accuracy 0.7276
# old, female, 0.5549, 1795
# old, male, 0.8708, 1795
# young, female, 0.8942, 1795
# young, male, 0.5905, 1795
# test
# Accuracy 0.7877
# old, female, 0.5658, 1916
# old, male, 0.8943, 2932
# young, female, 0.8918, 10331
# young, male, 0.5865, 4783
#
# ====celeba_svm_balanced=====
# val
# Accuracy 0.7370
# old, female, 0.5621, 1795
# old, male, 0.8758, 1795
# young, female, 0.9031, 1795
# young, male, 0.6072, 1795
# test
# Accuracy 0.7884
# old, female, 0.5830, 1916
# old, male, 0.8885, 2932
# young, female, 0.8909, 10331
# young, male, 0.5881, 4783
#
# ====celeba_svm_balanced=====
# val
# Accuracy 0.7245
# old, female, 0.5432, 1795
# old, male, 0.8657, 1795
# young, female, 0.8958, 1795
# young, male, 0.5933, 1795
# test
# Accuracy 0.7912
# old, female, 0.5699, 1916
# old, male, 0.8834, 2932
# young, female, 0.8962, 10331
# young, male, 0.5963, 4783
#
# ====celeba_svm_oracle_2=====
# val
# Accuracy 0.7309
# old, female, 0.5577, 1795
# old, male, 0.8836, 1795
# young, female, 0.8986, 1795
# young, male, 0.5838, 1795
# test
# Accuracy 0.7943
# old, female, 0.5605, 1916
# old, male, 0.8987, 2932
# young, female, 0.9016, 10331
# young, male, 0.5921, 4783
#
# ====celeba_svm_oracle_2=====
# val
# Accuracy 0.7373
# old, female, 0.5549, 1795
# old, male, 0.8875, 1795
# young, female, 0.9092, 1795
# young, male, 0.5978, 1795
# test
# Accuracy 0.7974
# old, female, 0.5788, 1916
# old, male, 0.8970, 2932
# young, female, 0.8968, 10331
# young, male, 0.6090, 4783
#
# ====celeba_svm_oracle_2=====
# val
# Accuracy 0.7352
# old, female, 0.5610, 1795
# old, male, 0.8875, 1795
# young, female, 0.9036, 1795
# young, male, 0.5889, 1795
# test
# Accuracy 0.7993
# old, female, 0.5804, 1916
# old, male, 0.9021, 2932
# young, female, 0.9033, 10331
# young, male, 0.5994, 4783
#
# ====celeba_svm_oracle_2=====
# val
# Accuracy 0.7351
# old, female, 0.5487, 1795
# old, male, 0.8919, 1795
# young, female, 0.9075, 1795
# young, male, 0.5922, 1795
# test
# Accuracy 0.7989
# old, female, 0.5668, 1916
# old, male, 0.8963, 2932
# young, female, 0.9047, 10331
# young, male, 0.6038, 4783
#
# ====celeba_svm_oracle_2=====
# val
# Accuracy 0.7343
# old, female, 0.5448, 1795
# old, male, 0.8830, 1795
# young, female, 0.9092, 1795
# young, male, 0.6000, 1795
# test
# Accuracy 0.7959
# old, female, 0.5605, 1916
# old, male, 0.9059, 2932
# young, female, 0.9006, 10331
# young, male, 0.5965, 4783
#
# ====celeba_svm_oracle_balance=====
# val
# Accuracy 0.7379
# old, female, 0.5805, 1795
# old, male, 0.8563, 1795
# young, female, 0.8975, 1795
# young, male, 0.6173, 1795
# test
# Accuracy 0.7976
# old, female, 0.6039, 1916
# old, male, 0.8895, 2932
# young, female, 0.8899, 10331
# young, male, 0.6195, 4783
#
# ====celeba_svm_oracle_balance=====
# val
# Accuracy 0.7453
# old, female, 0.5822, 1795
# old, male, 0.8735, 1795
# young, female, 0.9031, 1795
# young, male, 0.6223, 1795
# test
# Accuracy 0.7950
# old, female, 0.5939, 1916
# old, male, 0.8895, 2932
# young, female, 0.8926, 10331
# young, male, 0.6067, 4783
#
# ====celeba_svm_oracle_balance=====
# val
# Accuracy 0.7354
# old, female, 0.5694, 1795
# old, male, 0.8685, 1795
# young, female, 0.8880, 1795
# young, male, 0.6156, 1795
# test
# Accuracy 0.7967
# old, female, 0.5767, 1916
# old, male, 0.8912, 2932
# young, female, 0.8947, 10331
# young, male, 0.6153, 4783
#
# ====celeba_svm_oracle_balance=====
# val
# Accuracy 0.7403
# old, female, 0.5783, 1795
# old, male, 0.8685, 1795
# young, female, 0.8919, 1795
# young, male, 0.6223, 1795
# test
# Accuracy 0.7932
# old, female, 0.6007, 1916
# old, male, 0.8864, 2932
# young, female, 0.8923, 10331
# young, male, 0.5990, 4783
#
# ====celeba_svm_oracle_balance=====
# val
# Accuracy 0.7350
# old, female, 0.5666, 1795
# old, male, 0.8669, 1795
# young, female, 0.8981, 1795
# young, male, 0.6084, 1795
# test
# Accuracy 0.7952
# old, female, 0.5866, 1916
# old, male, 0.8840, 2932
# young, female, 0.8916, 10331
# young, male, 0.6161, 4783
#
# ====celeba_svm_overweight_2=====
# val
# Accuracy 0.7376
# old, female, 0.5655, 1795
# old, male, 0.8919, 1795
# young, female, 0.9092, 1795
# young, male, 0.5838, 1795
# test
# Accuracy 0.7928
# old, female, 0.5637, 1916
# old, male, 0.8950, 2932
# young, female, 0.9055, 10331
# young, male, 0.5785, 4783
#
# ====celeba_svm_overweight_2=====
# val
# Accuracy 0.7405
# old, female, 0.5710, 1795
# old, male, 0.8886, 1795
# young, female, 0.9019, 1795
# young, male, 0.6006, 1795
# test
# Accuracy 0.7978
# old, female, 0.5715, 1916
# old, male, 0.8973, 2932
# young, female, 0.9022, 10331
# young, male, 0.6017, 4783
#
# ====celeba_svm_overweight_2=====
# val
# Accuracy 0.7290
# old, female, 0.5549, 1795
# old, male, 0.8836, 1795
# young, female, 0.8975, 1795
# young, male, 0.5799, 1795
# test
# Accuracy 0.7928
# old, female, 0.5720, 1916
# old, male, 0.9120, 2932
# young, female, 0.8996, 10331
# young, male, 0.5775, 4783
#
# ====celeba_svm_overweight_2=====
# val
# Accuracy 0.7311
# old, female, 0.5437, 1795
# old, male, 0.8763, 1795
# young, female, 0.9136, 1795
# young, male, 0.5905, 1795
# test
# Accuracy 0.7986
# old, female, 0.5663, 1916
# old, male, 0.9048, 2932
# young, female, 0.9070, 10331
# young, male, 0.5925, 4783
#
# ====celeba_svm_overweight_2=====
# val
# Accuracy 0.7366
# old, female, 0.5560, 1795
# old, male, 0.8847, 1795
# young, female, 0.9109, 1795
# young, male, 0.5950, 1795
# test
# Accuracy 0.7963
# old, female, 0.5673, 1916
# old, male, 0.8939, 2932
# young, female, 0.9027, 10331
# young, male, 0.5982, 4783
#
# ====celeba_svm_soft=====
# val
# Accuracy 0.7304
# old, female, 0.5348, 1795
# old, male, 0.8875, 1795
# young, female, 0.9070, 1795
# young, male, 0.5922, 1795
# test
# Accuracy 0.7966
# old, female, 0.5621, 1916
# old, male, 0.9028, 2932
# young, female, 0.9054, 10331
# young, male, 0.5902, 4783
#
# ====celeba_svm_soft=====
# val
# Accuracy 0.7292
# old, female, 0.5476, 1795
# old, male, 0.8791, 1795
# young, female, 0.9014, 1795
# young, male, 0.5889, 1795
# test
# Accuracy 0.7912
# old, female, 0.5668, 1916
# old, male, 0.8919, 2932
# young, female, 0.9016, 10331
# young, male, 0.5810, 4783
#
# ====celeba_svm_soft=====
# val
# Accuracy 0.7263
# old, female, 0.5526, 1795
# old, male, 0.8791, 1795
# young, female, 0.9070, 1795
# young, male, 0.5666, 1795
# test
# Accuracy 0.7851
# old, female, 0.5637, 1916
# old, male, 0.8997, 2932
# young, female, 0.8965, 10331
# young, male, 0.5628, 4783
#
# ====celeba_svm_soft=====
# val
# Accuracy 0.7267
# old, female, 0.5460, 1795
# old, male, 0.8914, 1795
# young, female, 0.9042, 1795
# young, male, 0.5655, 1795
# test
# Accuracy 0.7914
# old, female, 0.5736, 1916
# old, male, 0.9035, 2932
# young, female, 0.9018, 10331
# young, male, 0.5714, 4783
#
# ====celeba_svm_soft=====
# val
# Accuracy 0.7255
# old, female, 0.5309, 1795
# old, male, 0.8769, 1795
# young, female, 0.9025, 1795
# young, male, 0.5916, 1795
# test
# Accuracy 0.7893
# old, female, 0.5574, 1916
# old, male, 0.8963, 2932
# young, female, 0.9031, 10331
# young, male, 0.5710, 4783

# %%
df_mask = (df['Split'] == 'val') & ((df['Method'] == 'celeba_age_1_4') | (df['Method'] == 'celeba_svm_oracle_2') | (df['Method'] == 'celeba_age_1_4'))
split_df = df.groupby(['Method', 'Split', 'Age and Gender']).mean().reset_index()
split_df['std'] = df.groupby(['Method', 'Split', 'Age and Gender']).std().reset_index()['Acc']
acc = split_df['Acc'].to_numpy()
std = split_df['std'].to_numpy()
comb = [f"\${acc[i]:0.3f} \pm {std[i]:0.3f}\$" for i in range(len(acc))]
split_df['comb'] = comb
display(split_df)
# Out:
#                        Method Split Age and Gender       Acc       std  \
# 0              celeba_age_1_4  test     old female  0.542380  0.009864
# 1              celeba_age_1_4  test       old male  0.904434  0.001995
# 2              celeba_age_1_4  test       overall   0.794520  0.001884
# 3              celeba_age_1_4  test   young female  0.914897  0.002285
# 4              celeba_age_1_4  test     young male  0.568137  0.005948
# 5              celeba_age_1_4   val     old female  0.527799  0.013362
# 6              celeba_age_1_4   val       old male  0.890919  0.006782
# 7              celeba_age_1_4   val       overall   0.726602  0.003817
# 8              celeba_age_1_4   val   young female  0.918440  0.003016
# 9              celeba_age_1_4   val     young male  0.569248  0.005127
# 10        celeba_svm_balanced  test     old female  0.574426  0.006940
# 11        celeba_svm_balanced  test       old male  0.889427  0.006446
# 12        celeba_svm_balanced  test       overall   0.788178  0.001824
# 13        celeba_svm_balanced  test   young female  0.891705  0.003186
# 14        celeba_svm_balanced  test     young male  0.588125  0.004756
# 15        celeba_svm_balanced   val     old female  0.557103  0.008540
# 16        celeba_svm_balanced   val       old male  0.872201  0.004290
# 17        celeba_svm_balanced   val       overall   0.731058  0.005102
# 18        celeba_svm_balanced   val   young female  0.895822  0.004279
# 19        celeba_svm_balanced   val     young male  0.599109  0.008867
# 20        celeba_svm_oracle_2  test     old female  0.569415  0.009652
# 21        celeba_svm_oracle_2  test       old male  0.900000  0.003973
# 22        celeba_svm_oracle_2  test       overall   0.797145  0.002115
# 23        celeba_svm_oracle_2  test   young female  0.901384  0.002996
# 24        celeba_svm_oracle_2  test     young male  0.600167  0.006539
# 25        celeba_svm_oracle_2   val     old female  0.553426  0.006575
# 26        celeba_svm_oracle_2   val       old male  0.886685  0.003602
# 27        celeba_svm_oracle_2   val       overall   0.734568  0.002331
# 28        celeba_svm_oracle_2   val   young female  0.905627  0.004536
# 29        celeba_svm_oracle_2   val     young male  0.592535  0.006563
# 30  celeba_svm_oracle_balance  test     old female  0.592380  0.010979
# 31  celeba_svm_oracle_balance  test       old male  0.888131  0.002864
# 32  celeba_svm_oracle_balance  test       overall   0.795532  0.001718
# 33  celeba_svm_oracle_balance  test   young female  0.892208  0.001716
# 34  celeba_svm_oracle_balance  test     young male  0.611332  0.008347
# 35  celeba_svm_oracle_balance   val     old female  0.575376  0.006974
# 36  celeba_svm_oracle_balance   val       old male  0.866741  0.006369
# 37  celeba_svm_oracle_balance   val       overall   0.738747  0.004219
# 38  celeba_svm_oracle_balance   val   young female  0.895710  0.005835
# 39  celeba_svm_oracle_balance   val     young male  0.617159  0.005755
# 40    celeba_svm_overweight_2  test     old female  0.568163  0.003551
# 41    celeba_svm_overweight_2  test       old male  0.900614  0.007667
# 42    celeba_svm_overweight_2  test       overall   0.795652  0.002731
# 43    celeba_svm_overweight_2  test   young female  0.903417  0.002890
# 44    celeba_svm_overweight_2  test     young male  0.589672  0.011168
# 45    celeba_svm_overweight_2   val     old female  0.558217  0.010519
# 46    celeba_svm_overweight_2   val       old male  0.885014  0.005877
# 47    celeba_svm_overweight_2   val       overall   0.734958  0.004793
# 48    celeba_svm_overweight_2   val   young female  0.906630  0.006692
# 49    celeba_svm_overweight_2   val     young male  0.589972  0.008301
# 50            celeba_svm_soft  test     old female  0.564718  0.006008
# 51            celeba_svm_soft  test       old male  0.898840  0.004815
# 52            celeba_svm_soft  test       overall   0.790712  0.004133
# 53            celeba_svm_soft  test   young female  0.901675  0.003267
# 54            celeba_svm_soft  test     young male  0.575287  0.010543
# 55            celeba_svm_soft   val     old female  0.542396  0.009142
# 56            celeba_svm_soft   val       old male  0.882785  0.006273
# 57            celeba_svm_soft   val       overall   0.727632  0.002072
# 58            celeba_svm_soft   val   young female  0.904401  0.002541
# 59            celeba_svm_soft   val     young male  0.580947  0.013694
#
#                    comb
# 0   \$0.542 \pm 0.010\$
# 1   \$0.904 \pm 0.002\$
# 2   \$0.795 \pm 0.002\$
# 3   \$0.915 \pm 0.002\$
# 4   \$0.568 \pm 0.006\$
# 5   \$0.528 \pm 0.013\$
# 6   \$0.891 \pm 0.007\$
# 7   \$0.727 \pm 0.004\$
# 8   \$0.918 \pm 0.003\$
# 9   \$0.569 \pm 0.005\$
# 10  \$0.574 \pm 0.007\$
# 11  \$0.889 \pm 0.006\$
# 12  \$0.788 \pm 0.002\$
# 13  \$0.892 \pm 0.003\$
# 14  \$0.588 \pm 0.005\$
# 15  \$0.557 \pm 0.009\$
# 16  \$0.872 \pm 0.004\$
# 17  \$0.731 \pm 0.005\$
# 18  \$0.896 \pm 0.004\$
# 19  \$0.599 \pm 0.009\$
# 20  \$0.569 \pm 0.010\$
# 21  \$0.900 \pm 0.004\$
# 22  \$0.797 \pm 0.002\$
# 23  \$0.901 \pm 0.003\$
# 24  \$0.600 \pm 0.007\$
# 25  \$0.553 \pm 0.007\$
# 26  \$0.887 \pm 0.004\$
# 27  \$0.735 \pm 0.002\$
# 28  \$0.906 \pm 0.005\$
# 29  \$0.593 \pm 0.007\$
# 30  \$0.592 \pm 0.011\$
# 31  \$0.888 \pm 0.003\$
# 32  \$0.796 \pm 0.002\$
# 33  \$0.892 \pm 0.002\$
# 34  \$0.611 \pm 0.008\$
# 35  \$0.575 \pm 0.007\$
# 36  \$0.867 \pm 0.006\$
# 37  \$0.739 \pm 0.004\$
# 38  \$0.896 \pm 0.006\$
# 39  \$0.617 \pm 0.006\$
# 40  \$0.568 \pm 0.004\$
# 41  \$0.901 \pm 0.008\$
# 42  \$0.796 \pm 0.003\$
# 43  \$0.903 \pm 0.003\$
# 44  \$0.590 \pm 0.011\$
# 45  \$0.558 \pm 0.011\$
# 46  \$0.885 \pm 0.006\$
# 47  \$0.735 \pm 0.005\$
# 48  \$0.907 \pm 0.007\$
# 49  \$0.590 \pm 0.008\$
# 50  \$0.565 \pm 0.006\$
# 51  \$0.899 \pm 0.005\$
# 52  \$0.791 \pm 0.004\$
# 53  \$0.902 \pm 0.003\$
# 54  \$0.575 \pm 0.011\$
# 55  \$0.542 \pm 0.009\$
# 56  \$0.883 \pm 0.006\$
# 57  \$0.728 \pm 0.002\$
# 58  \$0.904 \pm 0.003\$
# 59  \$0.581 \pm 0.014\$

# %%
results
# Out:
# [['old', 'female', 0.55741125],
#  ['old', 'male', 0.8963165],
#  ['young', 'female', 0.90310717],
#  ['young', 'male', 0.57098055],
#  ['overall', '', 0.78934973]]

# %%
# display extremes for original model
os.makedirs("figures/celeba", exist_ok=True)
for c in range(2):
    processor.display_extremes(c, split='test', rows=1, columns=4, filename=f"figures/celeba/{c}_extremes")
# Out:
# ---- CONFIDENCE ------
# ---- SVM ------
# ---- CONFIDENCE ------
# ---- SVM ------

# %% [markdown]
# ## CLIP

# %%
clip_analyzer = clip_utils.ClipAnalyzer(
    processor=processor, svm_model_name=svm_model_name, class_names=['person', 'person'],
    clip_config_name='CELEBA', do_normalize=True, exclude_common=True)
# Out:
# 100%|██████████| 621/621 [00:12<00:00, 51.10it/s]
# 100%|██████████| 72/72 [00:01<00:00, 46.32it/s]
# 100%|██████████| 200/200 [00:03<00:00, 50.44it/s]
# consistent with old results 0.9997937293729373
#   0%|          | 0/2 [00:00<?, ?it/s]
# person
# 100%|██████████| 2/2 [00:00<00:00, 25.87it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 101.08it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 120.85it/s]
#
# 100%|██████████| 1/1 [00:00<00:00, 79.12it/s]
#  50%|█████     | 1/2 [00:08<00:08,  8.22s/it]
# reference
# 100%|██████████| 1/1 [00:00<00:00, 102.45it/s]
# 100%|██████████| 2/2 [00:10<00:00,  5.10s/it]

# %%
def get_cdf(arr, K_range=None):
    out = []
    if K_range is None:
        K_range = np.arange(10, len(arr), 10)
    for K in K_range:
        out.append(arr[:K].mean())
    out = np.array(out)
    return out, K_range

# %%
split = 'test'
test_dv = processor.metrics[f'{split}_metrics']['decision_values']
test_confs = processor.run_dict[split]['confs']
test_class = processor.metrics[f'{split}_metrics']['classes'] # 0 if female, 1 if male
test_pred_correct = processor.metrics[f'{split}_metrics']['ypred']
test_correct = processor.metrics[f'{split}_metrics']['ytrue']

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

saved_caption_and_most_relevant_imgs = {}
df_dict = {}
for METHOD in ['CLASSIFY']: # CLOSEST
    all_dfs = []
    for target_class in range(2):
        print(processor.metrics['cv_scores'][target_class])

        if METHOD == 'CLOSEST':
            print("performing closest")
            result = clip_analyzer.perform_closest_to_top_K(target_class, 'all')
        else:
            print("performing classify captions on svm")
            result = clip_analyzer.get_svm_style_top_K(target_class, 'all')
        print("--------")

        cdfs = {}
        class_mask = test_class==target_class
        masked_indices = np.arange(len(test_class))[class_mask]
        # K_range = np.arange(10, len(masked_indices), 10)
        K_range=np.arange(20, 200, 5)
        for caption_index in range(1):
            for direction in ['pos', 'neg']:
                caption_text = result[f'{direction}_captions'][caption_index]
                print(f"{direction}: {caption_text}")
                top_caption_latent = torch.tensor(result[f'{direction}_latents'][caption_index]).cuda()

                image_latents = clip_analyzer.clip_features['test'][class_mask].cuda()
                image_angles = clip_utils.order_descriptions_angle(mean_point=top_caption_latent.unsqueeze(0), query_points=image_latents)
                image_order = np.argsort(image_angles)[::-1]
                saved_caption_and_most_relevant_imgs[(METHOD, target_class, caption_index, direction)] = (masked_indices[image_order], caption_text)
                cdfs[direction], _ = get_cdf(test_correct[masked_indices[image_order]], K_range)
                # uncomment this to display the images
#                 processor._display_images(taken_index=masked_indices[image_order], taken_scores=image_angles[image_order],
#                             taken_confs=image_angles[image_order], split="test")

            df = pd.DataFrame()
            df['K'] = K_range
            for d, v in cdfs.items():
                df[d] = v
            df = df.melt('K', var_name='Direction', value_name='Accuracy')
            all_dfs.append(df)
            sns.lineplot(data=df, x='K', y='Accuracy', hue='Direction')
            plt.axhline(y=test_correct[masked_indices].mean(), xmin=0, xmax=K_range[-1], color='gray')
            plt.show()
    df_dict[METHOD] = all_dfs
# Out:
# 0.710471342383107
# performing classify captions on svm
# person a photo of a person
# {'neg_captions': array(['a photo of a young woman who has an oval face',
#        'a photo of a young woman who has heavy makeup on',
#        'a photo of a young woman who has brown hair',
#        'a photo of a young woman who has narrow eyes',
#        'a photo of a young woman who has arched eyebrows',
#        'a photo of a young woman who has high cheekbones',
#        'a photo of a woman who has bangs',
#        'a photo of a woman who has high cheekbones',
#        'a photo of a woman who has narrow eyes',
#        'a photo of a young woman who has bushy eyebrows'], dtype='<U63'),
#  'neg_latents': array([[-0.1784668 ,  0.2866211 , -0.17687988, ..., -0.5834961 ,
#         -0.02586365, -0.18969727],
#        [-0.0491333 ,  0.40673828, -0.2734375 , ..., -0.33618164,
#         -0.00709152, -0.1496582 ],
#        [ 0.00703049,  0.34106445, -0.08081055, ..., -0.5317383 ,
#         -0.22106934, -0.03186035],
#        ...,
#        [ 0.10876465,  0.60302734, -0.0428772 , ..., -0.56152344,
#         -0.10980225, -0.5595703 ],
#        [ 0.02548218,  0.2130127 , -0.2479248 , ..., -0.3071289 ,
#         -0.15270996, -0.09185791],
#        [ 0.1574707 ,  0.21765137, -0.17004395, ..., -0.4560547 ,
#         -0.16125488,  0.04626465]], dtype=float32),
#  'neg_vals': array([-0.17351703, -0.16380124, -0.15889919, -0.15672802, -0.15121577,
#        -0.14606689, -0.14197615, -0.14012489, -0.13625294, -0.13077436]),
#  'pos_captions': array(['a photo of a old man who has no beard',
#        'a photo of a man who has no beard',
#        'a photo of a old man who has gray hair',
#        'a photo of a old man who has black hair',
#        'a photo of a old person who has no beard',
#        'a photo of a man who has gray hair',
#        'a photo of a old man who has a receding hairline',
#        'a photo of a old man who has brown hair',
#        'a photo of a old man who has a mustache',
#        'a photo of a old man who has a mouth that is slightly open'],
#       dtype='<U63'),
#  'pos_latents': array([[-0.01000214,  0.03189087, -0.22741699, ..., -0.5439453 ,
#          0.0413208 , -0.07202148],
#        [ 0.09014893,  0.13378906, -0.09240723, ..., -0.74560547,
#         -0.11096191, -0.10943604],
#        [-0.20361328, -0.02182007, -0.30322266, ..., -0.28735352,
#         -0.09173584,  0.04693604],
#        ...,
#        [-0.09240723,  0.23010254,  0.07928467, ..., -0.30200195,
#         -0.11993408, -0.12164307],
#        [-0.00518036, -0.04586792, -0.17419434, ..., -0.3786621 ,
#         -0.09613037, -0.07141113],
#        [-0.1451416 ,  0.01870728, -0.18908691, ..., -0.53808594,
#          0.06646729, -0.3425293 ]], dtype=float32),
#  'pos_vals': array([0.4026905 , 0.3467605 , 0.32019609, 0.31639988, 0.31090493,
#        0.30732847, 0.30543599, 0.29322721, 0.28380432, 0.27954706])}
# --------
# pos: a photo of a old man who has no beard
# neg: a photo of a young woman who has an oval face
# 0.6846768510309396
# performing classify captions on svm
# person a photo of a person
# {'neg_captions': array(['a photo of a man who has no beard',
#        'a photo of a man who has a mouth that is slightly open',
#        'a photo of a man who has a smile',
#        'a photo of a man who has a mustache',
#        'a photo of a man who has a receding hairline',
#        'a photo of a man who is wearing eyeglasses',
#        'a photo of a man who has narrow eyes',
#        'a photo of a old man who has no beard',
#        'a photo of a young man who has no beard',
#        'a photo of a man who has a big nose'], dtype='<U63'),
#  'neg_latents': array([[ 0.09014893,  0.13378906, -0.09240723, ..., -0.74560547,
#         -0.11096191, -0.10943604],
#        [ 0.01457214,  0.21032715, -0.09381104, ..., -0.7192383 ,
#         -0.08239746, -0.38354492],
#        [-0.24133301,  0.33520508, -0.20739746, ..., -0.91796875,
#         -0.16149902, -0.01461029],
#        ...,
#        [-0.01000214,  0.03189087, -0.22741699, ..., -0.5439453 ,
#          0.0413208 , -0.07202148],
#        [ 0.09869385,  0.09356689, -0.19567871, ..., -0.7792969 ,
#         -0.01263428, -0.07495117],
#        [-0.01649475,  0.18823242, -0.02383423, ..., -0.6894531 ,
#         -0.2783203 , -0.57714844]], dtype=float32),
#  'neg_vals': array([-0.68092721, -0.61575048, -0.61419739, -0.60003866, -0.53208825,
#        -0.52511048, -0.52503104, -0.51963897, -0.51087919, -0.50877354]),
#  'pos_captions': array(['a photo of a young woman who has an oval face',
#        'a photo of a young woman who has brown hair',
#        'a photo of a young woman who has heavy makeup on',
#        'a photo of a young woman who has arched eyebrows',
#        'a photo of a young woman who has straight hair',
#        'a photo of a young woman who has black hair',
#        'a photo of a young woman who has high cheekbones',
#        'a photo of a young woman who has bushy eyebrows',
#        'a photo of a young woman who has narrow eyes',
#        'a photo of a young woman who has gray hair'], dtype='<U63'),
#  'pos_latents': array([[-0.1784668 ,  0.2866211 , -0.17687988, ..., -0.5834961 ,
#         -0.02586365, -0.18969727],
#        [ 0.00703049,  0.34106445, -0.08081055, ..., -0.5317383 ,
#         -0.22106934, -0.03186035],
#        [-0.0491333 ,  0.40673828, -0.2734375 , ..., -0.33618164,
#         -0.00709152, -0.1496582 ],
#        ...,
#        [ 0.1574707 ,  0.21765137, -0.17004395, ..., -0.4560547 ,
#         -0.16125488,  0.04626465],
#        [-0.04400635,  0.21289062, -0.20617676, ..., -0.4506836 ,
#         -0.14318848, -0.00820923],
#        [-0.04678345,  0.16748047, -0.32348633, ..., -0.4753418 ,
#         -0.2783203 ,  0.12481689]], dtype=float32),
#  'pos_vals': array([0.24467773, 0.22290338, 0.20904628, 0.20145755, 0.1901044 ,
#        0.18657552, 0.18034291, 0.17871011, 0.14165461, 0.11776654])}
# --------
# pos: a photo of a young woman who has an oval face
# neg: a photo of a man who has no beard

# %% [markdown]
# ## Interventions

# %%
split = 'train'
orders = processor.orders['train']['SVM'][True] # most negative first
dv = processor.metrics[f'{split}_metrics']['decision_values']
classes = processor.metrics[f'{split}_metrics']['classes']
age_masks, gender_masks = train_masks
confs = processor.run_dict[split]['confs']

# %%
import seaborn as sns
import torch
import numpy as np
def get_automatic_loss_vec(filename=None):
    overall_loss_vec = np.ones(len(classes)) * -1.0
    for c in range(processor.hparams['num_classes']):
        mask = classes == c
        dv_vals = -dv[mask]
        dv_vals = dv_vals - dv_vals.min()
        dv_vals = dv_vals/dv_vals.mean()
        overall_loss_vec[mask] = dv_vals

    train_indices = torch.load(processor.metrics['args']['indices_file'])['train_indices']
    big_loss_vec = torch.ones(train_indices.max()+1) * -1
    big_loss_vec[train_indices] = torch.tensor(overall_loss_vec).float()
    if filename is not None:
        print(filename)
        torch.save(big_loss_vec, filename)

    for a in age_masks.keys():
        for g in gender_masks.keys():
            print(a, g, big_loss_vec[train_indices][age_masks[a] & gender_masks[g]].mean())

def get_simple_loss_vec(upweight=2, filename=None, balance=False):
    overall_loss_vec = np.ones(len(classes)) * -1.0
    for c in range(processor.hparams['num_classes']):
        mask = classes == c
        if balance:
            minority  = (mask & (dv <= 0)).sum()
            majority = (mask & (dv > 0)).sum()
            overall_loss_vec[mask & (dv <= 0)] = (minority + majority)/(minority*2)
            overall_loss_vec[mask & (dv > 0)] = (minority + majority)/(majority*2)
        else:
            overall_loss_vec[mask & (dv <= 0)] = upweight
            overall_loss_vec[mask & (dv > 0)] = 1

    train_indices = torch.load(processor.metrics['args']['indices_file'])['train_indices']
    big_loss_vec = torch.ones(train_indices.max()+1) * -1
    big_loss_vec[train_indices] = torch.tensor(overall_loss_vec).float()
    if filename is not None:
        print(filename)
        torch.save(big_loss_vec, filename)

    for a in age_masks.keys():
        for g in gender_masks.keys():
            print(a, g, big_loss_vec[train_indices][age_masks[a] & gender_masks[g]].mean())
    print("---")
    
def get_simple_loss_vec_confs(upweight=2, filename=None, balance=False):
    overall_loss_vec = np.ones(len(classes)) * -1.0
    for c in range(processor.hparams['num_classes']):
        mask = classes == c
        if balance:
            minority  = (mask & (confs <= 0.5)).sum()
            majority = (mask & (confs > 0.5)).sum()
            overall_loss_vec[mask & (confs <= 0.5)] = (minority + majority)/(minority*2)
            overall_loss_vec[mask & (confs > 0.5)] = (minority + majority)/(majority*2)
        else:
            overall_loss_vec[mask & (confs <= 0.5)] = upweight
            overall_loss_vec[mask & (confs > 0.5)] = 1

    train_indices = torch.load(processor.metrics['args']['indices_file'])['train_indices']
    big_loss_vec = torch.ones(train_indices.max()+1) * -1
    big_loss_vec[train_indices] = torch.tensor(overall_loss_vec).float()
    if filename is not None:
        print(filename)
        torch.save(big_loss_vec, filename)

    for a in age_masks.keys():
        for g in gender_masks.keys():
            print(a, g, big_loss_vec[train_indices][age_masks[a] & gender_masks[g]].mean())
    print("---")
            
def get_oracle_loss_vec(upweight=2, filename=None, balance=False):
    overall_loss_vec = np.ones(len(classes)) * -1.0
    if balance:
        minority = (age_masks['old'] & gender_masks['female']).sum()
        majority = (age_masks['old'] & gender_masks['male']).sum()
        overall_loss_vec[age_masks['old'] & gender_masks['female']] = (minority + majority)/(minority*2)
        overall_loss_vec[age_masks['old'] & gender_masks['male']] = (minority + majority)/(majority*2)
        
        majority = (age_masks['young'] & gender_masks['female']).sum()
        minority = (age_masks['young'] & gender_masks['male']).sum()
        overall_loss_vec[age_masks['young'] & gender_masks['female']] = (minority + majority)/(majority*2)
        overall_loss_vec[age_masks['young'] & gender_masks['male']] = (minority + majority)/(minority*2)
        
    else:
        overall_loss_vec[age_masks['old'] & gender_masks['female']] = upweight
        overall_loss_vec[age_masks['old'] & gender_masks['male']] = 1
        overall_loss_vec[age_masks['young'] & gender_masks['female']] = 1
        overall_loss_vec[age_masks['young'] & gender_masks['male']] = upweight

    train_indices = torch.load(processor.metrics['args']['indices_file'])['train_indices']
    big_loss_vec = torch.ones(train_indices.max()+1) * -1
    big_loss_vec[train_indices] = torch.tensor(overall_loss_vec).float()
    if filename is not None:
        print(filename)
        torch.save(big_loss_vec, filename)

    for a in age_masks.keys():
        for g in gender_masks.keys():
            print(a, g, big_loss_vec[train_indices][age_masks[a] & gender_masks[g]].mean())
    print("---")

# %%
filename=None
filename=os.path.join(loss_upweight_root, "soft.pt")
get_automatic_loss_vec(filename=filename) # get soft upweighting
filename=os.path.join(loss_upweight_root, "overweight_2.pt")
get_simple_loss_vec(upweight=2, filename=filename)
filename=os.path.join(loss_upweight_root, "balanced.pt")
get_simple_loss_vec(balance=True, filename=filename)
filename=os.path.join(loss_upweight_root, "oracle_2.pt")
get_oracle_loss_vec(upweight=2, filename=filename) # oracle upweight to 2
filename=os.path.join(loss_upweight_root, "oracle_balance.pt")
get_oracle_loss_vec(balance=True, filename=filename) # oracle upweight balanced
# Out:
# /mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/loss_vec_files/soft.pt
# old female tensor(1.7386)
# old male tensor(0.8154)
# young female tensor(0.8328)
# young male tensor(1.6688)
# /mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/loss_vec_files/overweight_2.pt
# old female tensor(1.8847)
# old male tensor(1.0371)
# young female tensor(1.0507)
# young male tensor(1.8478)
# ---
# /mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/loss_vec_files/balanced.pt
# old female tensor(2.2134)
# old male tensor(0.6967)
# young female tensor(0.7216)
# young male tensor(2.1137)
# ---
# /mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/loss_vec_files/oracle_2.pt
# old female tensor(2.)
# old male tensor(1.)
# young female tensor(1.)
# young male tensor(2.)
# ---
# /mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/loss_vec_files/oracle_balance.pt
# old female tensor(2.5000)
# old male tensor(0.6250)
# young female tensor(0.6250)
# young male tensor(2.5000)
# ---

# %%
filename = os.path.join(loss_upweight_root, "conf_upweight_2.pt")
get_simple_loss_vec_confs(upweight=2, filename=filename)
# Out:
# /mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/loss_vec_files/conf_upweight_2.pt
# old female tensor(1.0002)
# old male tensor(1.)
# young female tensor(1.0000)
# young male tensor(1.)
# ---

# %% [markdown]
# ## Confusion Matrix

# %%
split = 'test'


test_dv = processor.metrics[f'{split}_metrics']['decision_values']
test_confs = processor.run_dict[split]['confs']
test_class = processor.metrics[f'{split}_metrics']['classes']
test_pred_correct = processor.metrics[f'{split}_metrics']['ypred']
test_age_mask, test_gender_mask = test_masks
test_problematic = (test_age_mask['old'] & test_gender_mask['female']) | (test_age_mask['young'] & test_gender_mask['male'])

test_correct = processor.metrics[f'{split}_metrics']['ytrue']

# %%
import sklearn.metrics as sklearn_metrics
import seaborn as sns
import matplotlib.pyplot as plt
conf_matrix = sklearn_metrics.confusion_matrix(y_true=(test_problematic == 0), y_pred=test_correct)
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
sns.heatmap(conf_matrix/conf_matrix.sum(), fmt='.2%', annot=True, cmap='Blues')
ax.yaxis.set_ticklabels(['Problematic', 'Not Problematic'])
ax.xaxis.set_ticklabels(['Incorrect', 'Correct'])
perc_incorr_that_is_prob = (test_problematic & (test_correct == 0)).sum()/(test_correct == 0).sum()
perc_prob_that_is_incorr = (test_problematic & (test_correct == 0)).sum()/(test_problematic).sum()
print(f"percentage incorrect that is problematic {perc_incorr_that_is_prob:0.3%}")
print(f"percentage problematic that is incorrect {perc_prob_that_is_incorr:0.3%}")
plt.show()

conf_matrix = sklearn_metrics.confusion_matrix(y_true=(test_problematic == 0), y_pred=test_pred_correct)
fig, ax = plt.subplots(1, 1, figsize=(5, 4))
sns.heatmap(conf_matrix/conf_matrix.sum(), fmt='.2%', annot=True, cmap='Blues')
ax.yaxis.set_ticklabels(['Problematic', 'Not Problematic'])
ax.xaxis.set_ticklabels(['Predicted Incorrect', 'Predicted Correct'])
perc_incorr_that_is_prob = (test_problematic & (test_pred_correct == 0)).sum()/(test_pred_correct == 0).sum()
perc_prob_that_is_incorr = (test_problematic & (test_pred_correct == 0)).sum()/(test_problematic).sum()
print(f"percentage flagged that is problematic {perc_incorr_that_is_prob:0.3%}")
print(f"percentage problematic that is flagged {perc_prob_that_is_incorr:0.3%}")
plt.show()
# Out:
# percentage incorrect that is problematic 71.386%
# percentage problematic that is incorrect 43.275%
# percentage flagged that is problematic 89.865%
# percentage problematic that is flagged 84.714%

# %%
import sklearn.metrics as sklearn_metrics
import seaborn as sns
import matplotlib.pyplot as plt
def print_confusion_matrices(class_mask=None, condition_name='Problematic', filename=None):
    if class_mask is None:
        class_mask = np.ones(len(test_problematic)).astype(bool)
        
    problematic = test_problematic[class_mask]
    correct = test_correct[class_mask]
    pred_correct = test_pred_correct[class_mask]
    dv_order = np.argsort(test_dv[class_mask])
    conf_order = np.argsort(test_confs[class_mask])
    
    print(f"Percentage that is {condition_name}: {problematic.mean():0.2%}")
    print(f"Percentage that is incorrect: {(correct==0).mean():0.2%}")
    print(f"Percentage that is flagged: {(pred_correct==0).mean():0.2%}")
    print("--")
    
    fig, ax_ = plt.subplots(1, 2, figsize=(12, 4))

    ax = ax_[0]
    conf_matrix = sklearn_metrics.confusion_matrix(y_true=(problematic == 0), y_pred=correct)
    sns.heatmap(conf_matrix/conf_matrix.sum(), fmt='.2%', annot=True, cmap='Blues', ax=ax)
    ax.yaxis.set_ticklabels([f'{condition_name}', f'Not {condition_name}'])
    ax.xaxis.set_ticklabels(['Incorrect', 'Correct'])
    perc_incorr_that_is_prob = (problematic & (correct == 0)).sum()/(correct == 0).sum()
    perc_prob_that_is_incorr = (problematic & (correct == 0)).sum()/(problematic).sum()
    print(f"percentage incorrect that is {condition_name} {perc_incorr_that_is_prob:0.3%}")
    print(f"percentage {condition_name} that is incorrect {perc_prob_that_is_incorr:0.3%}")

    print("-")
    conf_matrix = sklearn_metrics.confusion_matrix(y_true=(problematic == 0), y_pred=pred_correct)
    ax = ax_[1]
    sns.heatmap(conf_matrix/conf_matrix.sum(), fmt='.2%', annot=True, cmap='Blues', ax=ax)
    ax.yaxis.set_ticklabels([f'{condition_name}', f'Not {condition_name}'])
    ax.xaxis.set_ticklabels(['Predicted Incorrect', 'Predicted Correct'])
    perc_incorr_that_is_prob = (problematic & (pred_correct == 0)).sum()/(pred_correct == 0).sum()
    perc_prob_that_is_incorr = (problematic & (pred_correct == 0)).sum()/(problematic).sum()
    print(f"percentage flagged that is {condition_name} {perc_incorr_that_is_prob:0.3%}")
    print(f"percentage {condition_name} that is flagged {perc_prob_that_is_incorr:0.3%}")
    plt.show()
    
    K_range = np.arange(10, len(problematic), 10) 
    df = []
    def compute_fraction(arr):
        return arr.sum()/len(arr)
    
    for K in K_range:
        df.append([
            K,
            compute_fraction(problematic[dv_order[:K]]),
            compute_fraction(problematic[conf_order[:K]]),
            compute_fraction(problematic),
        ])
    df = pd.DataFrame(df, columns=['Top K Flagged', 'SVM Decision Value', 'Confidence', 'Base Population'])
    df = df.melt(['Top K Flagged'], var_name='Order', value_name=f'Fraction {condition_name}')
    fig, ax = plt.subplots(1, 1)
    sns.lineplot(data=df, x='Top K Flagged', y=f'Fraction {condition_name}', hue='Order', 
                 hue_order=['SVM Decision Value', 'Confidence', 'Base Population'], palette=[BLUE, RED, GRAY],
                 ax=ax)
#     handles, labels = ax.get_legend_handles_labels()
#     ax.legend(handles=handles, labels=labels)
    if filename is not None:
        plt.savefig(filename, bbox_inches='tight')
    
    plt.show()

# %%
print("old")
df_0 = print_confusion_matrices(test_class==0, condition_name='Female', filename=f"figures/celeba/{0}_frac_plot.pdf")
print("young")
df_1 = print_confusion_matrices(test_class==1, condition_name='Male', filename=f"figures/celeba/{1}_frac_plot.pdf")
print("all")
_ = print_confusion_matrices(None)
# Out:
# old
# Percentage that is Female: 39.52%
# Percentage that is incorrect: 23.33%
# Percentage that is flagged: 38.04%
# --
# percentage incorrect that is Female 75.066%
# percentage Female that is incorrect 44.311%
# -
# percentage flagged that is Female 93.818%
# percentage Female that is flagged 90.292%
# young
# Percentage that is Male: 31.65%
# Percentage that is incorrect: 19.39%
# Percentage that is flagged: 29.58%
# --
# percentage incorrect that is Male 69.966%
# percentage Male that is incorrect 42.860%
# -
# percentage flagged that is Male 88.235%
# percentage Male that is flagged 82.480%
# all
# Percentage that is Problematic: 33.56%
# Percentage that is incorrect: 20.34%
# Percentage that is flagged: 31.64%
# --
# percentage incorrect that is Problematic 71.386%
# percentage Problematic that is incorrect 43.275%
# -
# percentage flagged that is Problematic 89.865%
# percentage Problematic that is flagged 84.714%

# %%
(torch.load("/mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_norm/loss_vec_files/oracle_balance.pt") == torch.load("/mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_no_norm/loss_vec_files/oracle_balance.pt")).all()
# Out:
# tensor(True)

# %%
torch.load("/mnt/cfs/projects/correlated_errors/experiments/celeba/celeba_age_no_norm/loss_vec_files/oracle_balance.pt")
# Out:
# tensor([ 0.6250,  0.6250,  2.5000,  ..., -1.0000,  0.6250,  0.6250])

# %% [markdown]
# # Domino

# %%
import meerkat as mk

# %%
# need  pip install scikit-learn==0.24.2

# %%
pred_probs = processor.run_dict['val']['pred_probs']

# %%
latents = torch.tensor(processor.run_dict['val']['latents']).float()
probs = torch.nn.Softmax(dim=1)(latents)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [87], in <module>
# ----> 1 latents = torch.tensor(processor.run_dict['val']['latents']).float()
#       2 probs = torch.nn.Softmax(dim=1)(latents)
#
# NameError: name 'torch' is not defined

# %%
c = 0
val_dp = mk.DataPanel({
    "emb": clip_analyzer.clip_features['val'].numpy(),
    "target": processor.run_dict['val']['ys'] == c,
    "pred_probs":pred_probs[:, c],  
})

# %%
from domino import DominoSlicer
domino = DominoSlicer(
    y_log_likelihood_weight=10,
    y_hat_log_likelihood_weight=10,
#     n_mixture_components=25,
    n_slices=2
)

# %%
domino.fit(data=val_dp, embeddings='emb', targets='target', pred_probs='pred_probs')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
test_dp = mk.DataPanel({
    "emb": clip_analyzer.clip_features['test'].numpy(),
    "target": processor.run_dict['test']['ys'] == c,
    "pred_probs":processor.run_dict['test']['pred_probs'][:, c],  
})
out = domino.predict_proba(data=test_dp, embeddings='emb', targets='target', pred_probs='pred_probs')
test_dp['domino_slices'] = out

# %%
from domino import generate_candidate_descriptions
phrase_templates = [
    "a photo of [MASK].",
    "a photo of {} [MASK].",
    "a photo of [MASK] {}.",
    "a photo of [MASK] {} [MASK].",
]

text_dp = generate_candidate_descriptions(
    templates=phrase_templates,
    num_candidates=10_000
)
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /mnt/nfs/home/saachij/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#   0%|          | 0/625 [00:00<?, ?it/s]

# %%
from domino import embed
text_dp = embed(
    text_dp, 
    input_col="output_phrase", 
    encoder="clip",
    device='cuda'
)
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]

# %%
from domino import describe
test_dp["target"] = test_dp["target"].astype(int)

descriptions = describe(
    data=test_dp,
    embeddings="emb",
    targets="target",
    slices="domino_slices",
    text=text_dp,
    text_embeddings="clip(output_phrase)",
    slice_idx=1
)
descriptions.lz[(-descriptions["score"]).argsort()][:10]
# Out:
# DataPanel(nrows: 10, ncols: 2)

# %%
test_problematic[np.argsort(out[:, 1])]
# Out:
# array([False, False,  True, ...,  True,  True,  True])

# %%
groups = [out[:, i] > 0.0001 for i in range(out.shape[-1])]
for g in groups:
    print("----")
    for a in [0,1]:
        for b in [0, 1]:
            print("age", a, "gender", b, g[(age == a) & (gender==b)].mean())
# Out:
# ----
# age 0 gender 0 0.0
# age 0 gender 1 0.0
# age 1 gender 0 0.0664988868454167
# age 1 gender 1 0.33807233953585614
# ----
# age 0 gender 0 0.3522964509394572
# age 0 gender 1 0.059686221009549796
# age 1 gender 0 0.0
# age 1 gender 1 0.0

# %%
split = 'test'


test_dv = processor.metrics[f'{split}_metrics']['decision_values']
test_confs = processor.run_dict[split]['confs']
test_class = processor.metrics[f'{split}_metrics']['classes']
test_pred_correct = processor.metrics[f'{split}_metrics']['ypred']
test_age_mask, test_gender_mask = test_masks
test_problematic = (test_age_mask['old'] & test_gender_mask['female']) | (test_age_mask['young'] & test_gender_mask['male'])

test_correct = processor.metrics[f'{split}_metrics']['ytrue']

# %%
def compute_fraction(arr):
    return arr.sum()/len(arr)
    
domino_order = np.argsort(out.max(1))[::-1]
dv_order = np.argsort(test_dv)
conf_order = np.argsort(test_confs)
df = []
for K in np.arange(5, len(test_problematic), 5):
    df.append([
        K,
        compute_fraction(test_problematic[domino_order[:K]]),
        compute_fraction(test_problematic[dv_order[:K]]),
        compute_fraction(test_problematic[conf_order[:K]]),
    ])
df = pd.DataFrame(df, columns=['K', 'Domino', 'SVM', 'CONF'])
df = df.melt('K', var_name='Method', value_name='Fraction Problematic')

# %%
df
# Out:
#            K  Method  Fraction Problematic
# 0          5  Domino              0.600000
# 1         10  Domino              0.700000
# 2         15  Domino              0.666667
# 3         20  Domino              0.600000
# 4         25  Domino              0.560000
# ...      ...     ...                   ...
# 11971  19940    CONF              0.335807
# 11972  19945    CONF              0.335824
# 11973  19950    CONF              0.335739
# 11974  19955    CONF              0.335655
# 11975  19960    CONF              0.335621
#
# [11976 rows x 3 columns]

# %%
sns.lineplot(data=df, x='K', y='Fraction Problematic', hue='Method')
# Out:
# <AxesSubplot:xlabel='K', ylabel='Fraction Problematic'>
